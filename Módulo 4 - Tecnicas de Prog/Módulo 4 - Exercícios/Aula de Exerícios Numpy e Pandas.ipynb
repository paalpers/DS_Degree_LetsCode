# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Problema 1
# Vamos praticar gerar matrizes e fazer operações com as linhas e colunas:
#
# (a) Crie uma matriz A com as dimensões (5, 4) e elementos aleatórios variando entre 0 e 50, com o 50 incluso;
#
# __Dica:__ Utilize as funções `np.random.randint` e `np.reshape`
#
# (b) Retorne a média do vetor
#
# (c) Retorne os menores valores de cada coluna;
#
# (d) Retorne os maiores valores de cada linha.

# %%
#A
np.random.seed(3)
matrix = np.random.randint(0, 51, size=(5, 4))
# OU
matrix2 = np.random.randint(0, 51, size=20).reshape(5,4)
matrix,matrix2
# Out:
# (array([[42, 24,  3,  8],
#         [ 0, 21, 19, 10],
#         [43, 41, 10, 21],
#         [38, 32, 20, 44],
#         [29, 39, 14, 26]]),
#  array([[17, 26, 22,  2],
#         [ 2,  1, 26,  5],
#         [40, 46, 33, 29],
#         [42, 24,  7, 43],
#         [33, 15, 48, 37]]))

# %%
#B
matrix.mean(),np.mean(matrix)
# Out:
# (24.2, 24.2)

# %%
#C
np.min(matrix, axis=0)
# Out:
# array([ 0, 21,  3,  8])

# %%
#D
np.max(matrix, axis=1)
# Out:
# array([42, 21, 43, 44, 39])

# %% [markdown]
# ### Problema 2
#
# Crie um objeto DataFrame que contenha os dados da tabela abaixo, os quais se referem ao peso, altura e idade de cinco pessoas:
#
#
# | Peso (kg) | Altura (cm) | Idade (anos) |
# |-----------|-------------|--------------|
# |  47 | 161	| 31 |
# |  80 | 170	| 21 |
# |  60 | 175	| 16 |
# |  90 | 162	| 28 |
# | 100 | 185	| 23 |
# | 147 | 189 | 32 |
#
# Com base no DataFrame criado, realize o que for pedido nos itens abaixo:
#
# (a) Visualize apenas os dados da coluna que contém a altura das pessoas;
#
# (b) Obtenha a idade média das pessoas;
#
# (c) Obtenha os dados das pessoas que estão abaixo da altura média;
#
# (d) Crie um nova coluna no DataFrame que contenha o IMC (Índice de Massa Corporal) de cada pessoa;
#
# __Obs.:__ A fórmula para o IMC é dada por IMC = Peso/(Altura)² com o peso em kg e a altura em metros.
#
# (e) Remova a coluna que contém a idade das pessoas;
#
# (f) Crie uma nova coluna chamada Classificação, que contenha a classificação de cada indivíduo, de acordo com o seu IMC. Para isso, consulte a tabela abaixo.
#
# | IMC             | Classificação |
# |-----------------|---------------|
# Menor que 18,5    | Subpeso |
# Entre 18,5 e 24,9 | Normal |
# Entre 25,0 e 29,9 | Sobrepeso |
# Entre 30,0 e 39,9 | Obesidade Grau I |
# Maior que 40,0    | Obesidade Grau II |
#
# (g) Salve esses dados do DataFrame em um arquivo csv.

# %%
df_clipboard = pd.read_clipboard()
tabela = df_clipboard.copy()
tabela
# Out:
#    Peso (kg)  Altura (cm)  Idade (anos)
# 0         47          161            31
# 1         80          170            21
# 2         60          175            16
# 3         90          162            28
# 4        100          185            23
# 5        147          189            32

# %%
#A
tabela[["Altura (cm)"]]
# Out:
#    Altura (cm)
# 0          161
# 1          170
# 2          175
# 3          162
# 4          185
# 5          189

# %%
#B
tabela[["Idade (anos)"]].mean()
# Out:
# Idade (anos)   25.17
# dtype: float64

# %%
#C
filtro = tabela["Altura (cm)"].mean()
tabela[tabela["Altura (cm)"] < filtro]
# Out:
#    Peso (kg)  Altura (cm)  Idade (anos)
# 0         47          161            31
# 1         80          170            21
# 3         90          162            28

# %%
tabela
# Out:
#    Peso (kg)  Altura (cm)  Idade (anos)
# 0         47          161            31
# 1         80          170            21
# 2         60          175            16
# 3         90          162            28
# 4        100          185            23
# 5        147          189            32

# %%
#D Crie um nova coluna no DataFrame que contenha o IMC (Índice de Massa Corporal) de cada pessoa;
# Obs.: A fórmula para o IMC é dada por IMC = Peso/(Altura)² com o peso em kg e a altura em metros.

tabela["IMC"] = (tabela["Peso (kg)"])/(tabela["Altura (cm)"]/100)**2

# %%
tabela
# Out:
#    Peso (kg)  Altura (cm)  Idade (anos)   IMC
# 0         47          161            31 18.13
# 1         80          170            21 27.68
# 2         60          175            16 19.59
# 3         90          162            28 34.29
# 4        100          185            23 29.22
# 5        147          189            32 41.15

# %%
#E Remova a coluna que contém a idade das pessoas;
tabela2 = tabela.copy()
tabela2.drop(columns=['Idade (anos)'],axis=1, inplace=True)
tabela2
# Out:
#    Peso (kg)  Altura (cm)   IMC
# 0         47          161 18.13
# 1         80          170 27.68
# 2         60          175 19.59
# 3         90          162 34.29
# 4        100          185 29.22
# 5        147          189 41.15

# %%
#F Crie uma nova coluna chamada Classificação, que contenha a classificação de cada indivíduo, de acordo com o seu IMC.
# Para isso, consulte a tabela abaixo.

def classificar(x):

    if x<18.5:
        return 'Subpeso'
    elif x<=24.9:
        return 'Normal'
    elif x<=29.9:
        return 'Sobrepeso'
    elif x<=39.9:
        return 'Obesidade Grau 1'
    else:
        return 'Obesidade Grau 2'

tabela2['Classificação'] = tabela2['IMC'].transform(classificar)
tabela2
# Out:
#    Peso (kg)  Altura (cm)   IMC     Classificação
# 0         47          161 18.13           Subpeso
# 1         80          170 27.68         Sobrepeso
# 2         60          175 19.59            Normal
# 3         90          162 34.29  Obesidade Grau 1
# 4        100          185 29.22         Sobrepeso
# 5        147          189 41.15  Obesidade Grau 2

# %%
#G Salve esses dados do DataFrame em um arquivo csv.

tabela2.to_csv('arquivo_prova_IMC.csv')

# %% [markdown]
# ### Problema 3
#
# O arquivo avocado.xlsx consiste em um dataset que contém dados sobre vendas de abacates  em diversas regiões dos Estados Unidos. Essa dataset contém as seguintes colunas:
#
# | Coluna | Descrição |
# |--------|-----------|
# | Date | data da observação |
# | AveragePrice | preço médio de um único abacate |
# | year | ano |
# | region | cidade ou região da observação |
# | Total Volume | volume total de abacates vendidos |
#
# Além das informações acima, contidas no arquivo avocado.xlsx, o tipo do abacate (convencional ou orgânico) também seria uma informação importante para a sua análise. Suponhamos que você conseguiu essas informações para cada uma das observações do arquivo avocado.csv, na mesma ordem, e salvou-as no arquivo avocado_type.xlsx. Portanto, tudo o que você precisa é juntar esses dois arquivos em um mesmo DataFrame.
#
# Com o DataFrame criado, obtenha o que é solicitado nos itens elencados abaixo:

# %%
avog = pd.read_csv('data/avocado.csv', delimiter=';')
avot = pd.read_excel('data/avocado_type.xlsx')
avot.shape, avog.shape
# Out:
# ((18249, 1), (18249, 5))

# %%
avog['Type'] = avot['type']
avog
# Out:
#              Date  AveragePrice  Total Volume  year            region  \
# 0      2015-12-27          1.33     64,236.62  2015            Albany
# 1      2015-12-20          1.35     54,876.98  2015            Albany
# 2      2015-12-13          0.93    118,220.22  2015            Albany
# 3      2015-12-06          1.08     78,992.15  2015            Albany
# 4      2015-11-29          1.28     51,039.60  2015            Albany
# ...           ...           ...           ...   ...               ...
# 18244  2018-02-04          1.63     17,074.83  2018  WestTexNewMexico
# 18245  2018-01-28          1.71     13,888.04  2018  WestTexNewMexico
# 18246  2018-01-21          1.87     13,766.76  2018  WestTexNewMexico
# 18247  2018-01-14          1.93     16,205.22  2018  WestTexNewMexico
# 18248  2018-01-07          1.62     17,489.58  2018  WestTexNewMexico
#
#                Type
# 0          orgânico
# 1      convencional
# 2      convencional
# 3          orgânico
# 4          orgânico
# ...             ...
# 18244  convencional
# 18245  convencional
# 18246  convencional
# 18247  convencional
# 18248  convencional
#
# [18249 rows x 6 columns]

# %% [markdown]
# (a) A quantidade de abacates do tipo convecional e do tipo orgânico.

# %%
avog.groupby('Type')['Type'].count()
# Out:
# Type
# convencional    9114
# orgânico        9135
# Name: Type, dtype: int64

# %% [markdown]
# (b) A quantidade de registros (linhas) de abacates vendidos para cada região ordenada da maior venda para a menor.

# %% [markdown]
# (c) Para que todos os labels das colunas fiquem padronizados, renomeie aqueles que estão iniciando em letra minúscula para que iniciem em letra maiúscula, trocando espaço por _ e adicionando _ como separação de texto.

# %%
avog.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'year', 'region', 'Type'], dtype='object')

# %%
avog.rename({'AveragePrice':'Average_Price','Total Volume':'Total_Volume','year':'Year','region':'Region'},axis=1, inplace=True)
avog
# Out:
#              Date  Average_Price  Total_Volume  Year            Region  \
# 0      2015-12-27           1.33     64,236.62  2015            Albany
# 1      2015-12-20           1.35     54,876.98  2015            Albany
# 2      2015-12-13           0.93    118,220.22  2015            Albany
# 3      2015-12-06           1.08     78,992.15  2015            Albany
# 4      2015-11-29           1.28     51,039.60  2015            Albany
# ...           ...            ...           ...   ...               ...
# 18244  2018-02-04           1.63     17,074.83  2018  WestTexNewMexico
# 18245  2018-01-28           1.71     13,888.04  2018  WestTexNewMexico
# 18246  2018-01-21           1.87     13,766.76  2018  WestTexNewMexico
# 18247  2018-01-14           1.93     16,205.22  2018  WestTexNewMexico
# 18248  2018-01-07           1.62     17,489.58  2018  WestTexNewMexico
#
#                Type
# 0          orgânico
# 1      convencional
# 2      convencional
# 3          orgânico
# 4          orgânico
# ...             ...
# 18244  convencional
# 18245  convencional
# 18246  convencional
# 18247  convencional
# 18248  convencional
#
# [18249 rows x 6 columns]

# %% [markdown]
# (d) Essa dado possui duplicados? Se sim, remova-os do dataset.

# %%
avog.duplicated().sum()
# avog.shape
# Out:
# 0

# %% [markdown]
# (e) Retire dos dados a região 'TotalUS'

# %%
avog2=avog.copy()
avog2 = avog2.set_index('Region')
avog2 = avog2.drop(index='TotalUS')
avog2.reset_index(inplace=True)

# outra forma de se fazer
df_remove = avog2.loc[(avog2['Region'] == 'TotalUS')]
avog2.drop(df_remove.index)
# Out:
#                  Region        Date  Average_Price  Total_Volume  Year  \
# 0                Albany  2015-12-27           1.33     64,236.62  2015
# 1                Albany  2015-12-20           1.35     54,876.98  2015
# 2                Albany  2015-12-13           0.93    118,220.22  2015
# 3                Albany  2015-12-06           1.08     78,992.15  2015
# 4                Albany  2015-11-29           1.28     51,039.60  2015
# ...                 ...         ...            ...           ...   ...
# 17906  WestTexNewMexico  2018-02-04           1.63     17,074.83  2018
# 17907  WestTexNewMexico  2018-01-28           1.71     13,888.04  2018
# 17908  WestTexNewMexico  2018-01-21           1.87     13,766.76  2018
# 17909  WestTexNewMexico  2018-01-14           1.93     16,205.22  2018
# 17910  WestTexNewMexico  2018-01-07           1.62     17,489.58  2018
#
#                Type
# 0          orgânico
# 1      convencional
# 2      convencional
# 3          orgânico
# 4          orgânico
# ...             ...
# 17906  convencional
# 17907  convencional
# 17908  convencional
# 17909  convencional
# 17910  convencional
#
# [17911 rows x 6 columns]

# %% [markdown]
# (g) Apresente as regiões que mais venderam abacate em todo o período em ordem decrescente.

# %%
avog2.groupby(['Region'])[['Total_Volume']].sum().sort_values('Total_Volume', ascending=False).head(10)
# Out:
#                  Total_Volume
# Region
# West         1,086,779,155.75
# California   1,028,981,653.17
# SouthCentral 1,011,279,618.83
# Northeast      713,280,909.56
# Southeast      615,238,409.11
# GreatLakes     589,642,549.29
# Midsouth       508,349,357.20
# LosAngeles     507,896,547.63
# Plains         311,188,529.11
# NewYork        240,734,127.53

# %% [markdown]
# (h) Calcule o volume total de abacates vendidos para cada tipo e ano.

# %%
avog2.groupby(['Type', 'Year'])[['Total_Volume']].sum().sort_values('Year', ascending=False)
# Out:
#                       Total_Volume
# Type         Year
# convencional 2018   433,710,441.83
# orgânico     2018   425,395,644.21
# convencional 2017 1,505,463,914.14
# orgânico     2017 1,564,148,221.75
# convencional 2016 1,538,913,526.12
# orgânico     2016 1,462,817,222.93
# convencional 2015 1,405,835,526.60
# orgânico     2015 1,322,377,914.02

# %% [markdown]
# (f) existe alguma região que foi a maior responsável pela queda na produção de 2018?

# %%
avog3=avog.copy()
avog3 = avog3.set_index('Year')
avog3 = avog3.drop(labels=['Date','Average_Price', 'Type'], axis=1)
avog3 = avog3.drop(index=[2015,2016])
avog3.reset_index(inplace=True)

# %%
pd.set_option('display.max_columns', None) # or 1000.
pd.set_option('display.max_rows', None) # or 1000.
pd.set_option('display.max_colwidth', -1) # or 199.
# Out:
# <ipython-input-63-cedd4352dfaa>:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1) # or 199.

# %%
avog3.pivot_table(index='Region',values='Total_Volume', columns=['Year'], aggfunc='sum').head()
# Out:
# Year                         2017          2018
# Region
# Albany              5,231,581.78  1,541,986.17
# Atlanta             28,815,119.98 8,231,422.45
# BaltimoreWashington 41,015,634.46 12,158,903.00
# Boise               4,760,561.31  1,214,759.57
# Boston              30,610,672.16 8,637,005.96

# %% [markdown]
# (g) Qual cidade menos faturou com a venda de abacates?

# %%
avog2['Faturamento']=avog2['Average_Price']*avog2['Total_Volume']
avog2.groupby(['Region'])[['Faturamento']].sum().sort_values('Faturamento', ascending=True).head(5)
# Out:
#              Faturamento
# Region
# Syracuse   15,205,192.60
# Boise      15,346,666.47
# Spokane    17,156,485.66
# Louisville 17,495,546.93
# Albany     21,766,723.75

# %% [markdown]
# ### Problema 4
#
# Com base no dataset 'Video_Games_Sales.csv' responda:

# %%
df = pd.read_csv('data/Video_Games_Sales.csv', delimiter=';')

# %% [markdown]
# (a) Quantos jogos existem em cada genero?

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0  Wii Sports                Wii     2,006.00          Sports        Nintendo
# 1  Super Mario Bros.         NES     1,985.00          Platform      Nintendo
# 2  Mario Kart Wii            Wii     2,008.00          Racing        Nintendo
# 3  Wii Sports Resort         Wii     2,009.00          Sports        Nintendo
# 4  Pokemon Red/Pokemon Blue  GB      1,996.00          Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0 41.36     28.96     3.77      8.45         82.53         76.00
# 1 29.08     3.58      6.81      0.77         40.24         nan
# 2 15.68     12.76     3.79      3.29         35.52         82.00
# 3 15.61     10.93     3.28      2.95         32.77         80.00
# 4 11.27     8.89      10.22     1.00         31.37         nan
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0 51.00         8.00        322.00       Nintendo  E
# 1 nan           nan         nan          NaN       NaN
# 2 73.00         8.30        709.00       Nintendo  E
# 3 73.00         8.00        192.00       Nintendo  E
# 4 nan           nan         nan          NaN       NaN

# %%
df.groupby('Genre')[['Name']].count()
# Out:
#               Name
# Genre
# Action        3370
# Adventure     1303
# Fighting      849
# Misc          1750
# Platform      888
# Puzzle        580
# Racing        1249
# Role-Playing  1500
# Shooter       1323
# Simulation    874
# Sports        2348
# Strategy      683

# %% [markdown]
# (b) Temos duplicados nesses dados? E nulos?

# %%
df.isna().sum()
# Out:
# Name               2
# Platform           0
# Year_of_Release    269
# Genre              2
# Publisher          54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Name               16717
# Platform           16719
# Year_of_Release    16450
# Genre              16717
# Publisher          16665
# NA_Sales           16719
# EU_Sales           16719
# JP_Sales           16719
# Other_Sales        16719
# Global_Sales       16719
# Critic_Score       8137
# Critic_Count       8137
# User_Score         7590
# User_Count         7590
# Developer          10096
# Rating             9950
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name               2
# Platform           0
# Year_of_Release    269
# Genre              2
# Publisher          54
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# (b) Quantos jogos de cada publisher receberam nota acima de 9 na avaliação dos usuarios?

# %%
df[df[['User_Score']] > 9].count()
# Out:
# Name               0
# Platform           0
# Year_of_Release    0
# Genre              0
# Publisher          0
# NA_Sales           0
# EU_Sales           0
# JP_Sales           0
# Other_Sales        0
# Global_Sales       0
# Critic_Score       0
# Critic_Count       0
# User_Score         184
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %% [markdown]
# (c) Faça uma tabela que mostre o total vendido por ano por pais/globalmente de cada publisher? Você consegue observar algum padrão? Com se comportaram as vendas na América do Norte (NA) ao longo do tempo? O mesmo foi visto nos demais lugares?

# %%
df[['Year_of_Release','Publisher','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].groupby(['Year_of_Release','Publisher']).sum().head()
# Out:
#                                               NA_Sales  EU_Sales  JP_Sales  \
# Year_of_Release Publisher
# 1,980.00        Activision                   2.82      0.18      0.00
#                 Atari                        7.77      0.49      0.00
# 1,981.00        20th Century Fox Video Games 1.27      0.07      0.00
#                 Activision                   7.95      0.46      0.00
#                 Atari                        7.87      0.47      0.00
#
#                                               Other_Sales  Global_Sales
# Year_of_Release Publisher
# 1,980.00        Activision                   0.03         3.02
#                 Atari                        0.09         8.36
# 1,981.00        20th Century Fox Video Games 0.01         1.35
#                 Activision                   0.08         8.50
#                 Atari                        0.08         8.45

# %%
df[['Year_of_Release','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].groupby(['Year_of_Release']).sum()
# Out:
#                  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year_of_Release
# 1,980.00        10.59     0.67      0.00      0.12         11.38
# 1,981.00        33.40     1.96      0.00      0.32         35.77
# 1,982.00        26.92     1.65      0.00      0.31         28.86
# 1,983.00        7.76      0.80      8.10      0.14         16.79
# 1,984.00        33.28     2.10      14.27     0.70         50.36
# 1,985.00        33.73     4.74      14.56     0.92         53.94
# 1,986.00        12.50     2.84      19.81     1.93         37.07
# 1,987.00        8.46      1.41      11.63     0.20         21.74
# 1,988.00        23.87     6.59      15.76     0.99         47.22
# 1,989.00        45.15     8.44      18.36     1.50         73.45
# 1,990.00        25.46     7.63      14.88     1.40         49.39
# 1,991.00        12.76     3.95      14.78     0.74         32.23
# 1,992.00        33.89     11.71     28.91     1.65         76.17
# 1,993.00        16.90     5.18      25.36     0.97         48.40
# 1,994.00        28.16     14.88     33.99     2.20         79.18
# 1,995.00        24.83     14.90     45.75     2.64         88.11
# 1,996.00        86.76     47.26     57.44     7.69         199.15
# 1,997.00        94.75     48.32     48.87     9.13         200.98
# 1,998.00        128.36    66.90     50.04     11.01        256.45
# 1,999.00        126.06    62.67     52.34     10.04        251.25
# 2,000.00        94.50     52.77     42.77     11.62        201.58
# 2,001.00        173.98    94.89     39.86     22.73        331.47
# 2,002.00        216.19    109.75    41.76     27.27        395.51
# 2,003.00        193.61    103.81    34.20     25.92        357.80
# 2,004.00        222.51    107.28    41.65     47.24        419.05
# 2,005.00        242.15    121.11    54.27     40.29        458.31
# 2,006.00        262.13    127.89    73.74     53.95        518.22
# 2,007.00        309.89    157.82    60.29     76.75        605.37
# 2,008.00        348.69    181.14    60.25     81.42        671.79
# 2,009.00        335.55    187.94    61.89     73.44        658.88
# 2,010.00        300.65    171.42    59.49     58.57        590.59
# 2,011.00        238.79    162.97    53.07     52.75        507.79
# 2,012.00        153.26    114.59    51.80     36.19        355.84
# 2,013.00        153.65    121.55    47.69     38.35        361.24
# 2,014.00        132.27    122.74    39.69     36.83        331.51
# 2,015.00        106.86    96.72     34.09     30.31        268.05
# 2,016.00        44.93     51.22     19.31     14.48        130.10
# 2,017.00        0.00      0.00      0.06      0.00         0.06
# 2,020.00        0.27      0.00      0.00      0.02         0.29

# %%
df[['Publisher','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].groupby(['Publisher']).sum().head()
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# 10TACLE Studios              0.07      0.04      0.00      0.00
# 1C Company                   0.01      0.07      0.00      0.01
# 20th Century Fox Video Games 1.82      0.10      0.00      0.01
# 2D Boy                       0.00      0.03      0.00      0.01
# 3DO                          6.48      3.04      0.00      0.63
#
#                               Global_Sales
# Publisher
# 10TACLE Studios              0.11
# 1C Company                   0.10
# 20th Century Fox Video Games 1.94
# 2D Boy                       0.04
# 3DO                          10.12

# %% [markdown]
# (d) Qual foi jogo mais vendido na união européia? De que ano ele é e qual a editora?

# %%
df[['Publisher','Year_of_Release','EU_Sales']].sort_values('EU_Sales', ascending=False).head(1)
# Out:
#   Publisher  Year_of_Release  EU_Sales
# 0  Nintendo 2,006.00         28.96

# %% [markdown]
# (e) Quantos % os generos ['Racing', 'Sports', 'Shooter'] representam na base de dados?

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0  Wii Sports                Wii     2,006.00          Sports        Nintendo
# 1  Super Mario Bros.         NES     1,985.00          Platform      Nintendo
# 2  Mario Kart Wii            Wii     2,008.00          Racing        Nintendo
# 3  Wii Sports Resort         Wii     2,009.00          Sports        Nintendo
# 4  Pokemon Red/Pokemon Blue  GB      1,996.00          Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0 41.36     28.96     3.77      8.45         82.53         76.00
# 1 29.08     3.58      6.81      0.77         40.24         nan
# 2 15.68     12.76     3.79      3.29         35.52         82.00
# 3 15.61     10.93     3.28      2.95         32.77         80.00
# 4 11.27     8.89      10.22     1.00         31.37         nan
#
#    Critic_Count  User_Score  User_Count Developer Rating  Count Genre
# 0 51.00         8.00        322.00       Nintendo  E     nan
# 1 nan           nan         nan          NaN       NaN   nan
# 2 73.00         8.30        709.00       Nintendo  E     nan
# 3 73.00         8.00        192.00       Nintendo  E     nan
# 4 nan           nan         nan          NaN       NaN   nan

# %%
rss = 0
total = 0

for index, genre in df[['Genre']].iterrows():
    if genre['Genre'] == 'Racing':
        rss += 1
        total += 1
    elif genre['Genre'] == 'Sports':
        rss += 1
        total += 1
    elif genre['Genre'] == 'Shooter':
        rss += 1
        total +=1
    else:
        total += 1
rss_total = (rss/total)*100
print(f'Quantidade de Racing, Sports, Shooterrs é de {rss} jogos')
print(f'Quantidade Total de jogos é {total} jogos')
print(f'Racing, Sports e Shooter representam {rss_total:.2f}% da base total')
# Out:
# Quantidade de Racing, Sports, Shooterrs é de 4920 jogos
# Quantidade Total de jogos é 16719 jogos
# Racing, Sports e Shooter representam 29.43% da base total

# %% [markdown]
# (f) Qual plataforma vendeu menos globalmente? obs: imprimir somente o nome

# %%
df.pivot_table(index='Platform', values = 'Global_Sales', aggfunc='sum').sort_values('Global_Sales').head(1)
# Out:
#           Global_Sales
# Platform
# PCFX     0.03

# %% [markdown]
# ### Problema 5
# A pasta 'data/datasus' contém informações sobre casos de dengue e tabelas auxiliares. <br>
#
# | Tabela | Conteúdo |
# |--------|----------|
# | Dengue | Quantidade de casos por município |
# | Agua | Quantidade de residências em cada município por tipo o abastecimento de água |
# | InstalacoesSanitarias | Quantidade de residências em cada município por tipo de rede de esgoto |
# | Pib | PIB per capita de cada município |
# | Municipios | Relaciona o id_municipio com seu nome e estado |
# | Populacao | Quantidade de pessoas morando em áreas urbanas, rurais e população total por município |
# | Sexo | Quantidade de pessoas por sexo em cada município |
#
# (a) Calcular o número de casos de dengue por cada estado apresentando os dados em ordem decrescente.

# %%
dengue = pd.read_csv('data/datasus/Dengue.csv', delimiter=',')
municipio = pd.read_csv('data/datasus/Municipios.csv', delimiter=',')

# %%
dengue.head(1)
# Out:
#    id_registro  id_municipio  casos
# 0            1             1     10

# %%
municipio.head(1)
# Out:
#    id_municipio                     municipio  UF
# 0             1  110001 Alta Floresta D'Oeste  RO

# %%
muni_dengue = dengue.merge(municipio[['id_municipio','municipio','UF']], how="outer", on="id_municipio").sort_values('casos', ascending=False).head(5)

# %%
muni_dengue.head(5)
# Out:
#       id_registro  id_municipio     casos                   municipio  UF
# 2455       2456.0          5566  239395.0           522200 Vianópolis  GO
# 2283       2284.0          5337   10859.0  520085 Americano do Brasil  GO
# 2337       2338.0          5413    9340.0              520810 Formoso  GO
# 499         500.0           949    4321.0            230435 Forquilha  CE
# 2192       2193.0          5215    3298.0              510325 Colniza  MT

# %% [markdown]
# (b) Utilizando o dataset InstalacoesSanitarias.csv, determine o número de pessoas que não possuem meio sanitário algum de descarte de dejetos por estado.

# %%
sanitario = pd.read_csv('data/datasus/InstalacoesSanitarias.csv', ',')

# %%
sanitario.head(2)
# Out:
#    id_registro  id_municipio  rede_geral  fossa_septica  fossa_rudimendar  \
# 0            1             1        60.0          563.0           21445.0
# 1            2             2        27.0           47.0           10910.0
#
#     vala  Rio_lago_mar  outros  nao_possui
# 0  346.0         102.0   747.0       791.0
# 1  485.0          31.0   682.0       576.0

# %%
sanitario.groupby('nao_possui').size()
# Out:
# nao_possui
# 1.0          105
# 2.0           95
# 3.0           79
# 4.0           76
# 5.0           88
#             ...
# 21797.0        1
# 23715.0        1
# 24359.0        1
# 26264.0        1
# 5779618.0      1
# Length: 2030, dtype: int64

# %%
sanitario.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5566 entries, 0 to 5565
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_registro       5566 non-null   int64
#  1   id_municipio      5566 non-null   int64
#  2   rede_geral        5453 non-null   float64
#  3   fossa_septica     5543 non-null   float64
#  4   fossa_rudimendar  5560 non-null   float64
#  5   vala              5344 non-null   float64
#  6   Rio_lago_mar      4362 non-null   float64
#  7   outros            5317 non-null   float64
#  8   nao_possui        5360 non-null   float64
# dtypes: float64(7), int64(2)
# memory usage: 391.5 KB

# %%
sanitario.size
# Out:
# 50094

# %% [markdown]
# (c) Crie uma coluna com a posição de ranking considerando o PIB. Os maiores PIB devem ter os menores valores de ranking.

# %%
pib = pd.read_csv('data/datasus/Pib.csv', ',')
# crieando coluna rank e invertendo a ordem do rank co o pib
pib['Rank'] = pib['pib_percapta'].rank(ascending=False)
# ordenando por Rank
pib.sort_values('Rank',inplace=True)

pib
# Out:
#       id_registro  id_municipio  pib_percapta    Rank
# 3152         3153          3155     715193.70     1.0
# 2962         2963          2965     340688.49     2.0
# 3574         3575          3577     278145.26     3.0
# 3230         3231          3233     255658.30     4.0
# 5163         5164          5169     254242.69     5.0
# ...           ...           ...           ...     ...
# 617           618           618       3566.34  5555.0
# 2106         2107          2109       3561.71  5556.0
# 563           564           564       3529.10  5557.0
# 643           644           644       3510.69  5558.0
# 572           573           573       3241.29  5559.0
#
# [5559 rows x 4 columns]

# %% [markdown]
# (d) Qual o PIB dos 5 municípios com mais casos de dengue e sua posição no ranking?

# %%
pib_casos = pib.merge(muni_dengue[['id_municipio','municipio','UF','casos']], how="outer", on="id_municipio").sort_values('casos', ascending=False).head(5)

# %%
pib_casos.sort_values('casos', ascending=False)
# Out:
#       id_registro  id_municipio  pib_percapta    Rank  \
# 904          5559          5566      26445.72   905.0
# 1571         5331          5337      19774.03  1572.0
# 741          5407          5413      29034.21   742.0
# 1601          949           949      19494.40  1602.0
# 640          5210          5215      31016.19   641.0
#
#                        municipio  UF     casos
# 904            522200 Vianópolis  GO  239395.0
# 1571  520085 Americano do Brasil  GO   10859.0
# 741               520810 Formoso  GO    9340.0
# 1601            230435 Forquilha  CE    4321.0
# 640               510325 Colniza  MT    3298.0
