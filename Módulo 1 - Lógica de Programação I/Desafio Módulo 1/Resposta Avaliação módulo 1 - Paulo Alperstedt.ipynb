# %% [markdown]
# # Avaliação módulo 1 - Degree Data Science
#
# Na empresa em que você trabalha foi solicitada a implementação de um sistema de cadastro dos fornecedores. As informações que devem ser cadastradas são:
#
# - Código do fornecedor;
# - Nome do fornecedor;
# - Telefone do fornecedor;
# - Email do fornecedor.
#
# Para isso, você deverá criar um script para armazenar essas informações em alguma estrutura de dados.
#
# Também como parte do sistema de cadastro, é necessário criar uma "interface de navegação" pelo sistema, que tenha as seguintes funcionalidades:
#
# - Permite a exibição (usando o `print`) de todas as informaçoes de contatos específicos, a partir da busca pelo código do fornecedor;
# - Permite a remoção e adição de fornecedores à estrutura de cadastro.
#
# Requisitos:
#
# - Requisito #1 - Não existe um limite para fornecedores cadastrados, portanto você deverá permitir que o usuário cadastre a quantidade que desejar.
# - Requisito #2 - Crie pelo menos uma função em seu script. Você deverá escolher pelo menos uma tarefa do seu script e implementar em uma função para chamá-la dentro da sua lógica de cadastro.
# - Requisito #3 - Crie pelo menos uma verificação em seu código, por exemplo: Se o dicionário estiver vazio, não permita a opção remover.
#
# Tópicos avaliados:
#
# - Variáveis;
# - Tipos de dados;
# - Operadores aritméticos;
# - I/O de dados;
# - Expressões lógicas e condicionais;
# - Laços de repetição;
# - Listas e dicionários;
# - Funções.

# %%
# requisito 2 função menu
def menu_inicial():

    print('''
    Selecione as opções de acordo com seus respectivos números:
    
        1 Registrar ou Remover um fornecedor.
        2 Informações gerais do fornecedor.
        0 Fechar programa.
    ''')
    

# requisito 1 não há limite para cadastros
#listas e dicionários
fornecedores = {"Código do fornecedor" : [],
                "Nome": [],
                "Telefone": [],
                "E-mail" : []
               }


menu_inicial()
resposta = input('''Informe a opção desejada (digite 0 para sair): ''')

while resposta != '0': 
    
    if (resposta == '1'):
        
        add_remove = input('''\tPara adicionar fornecedor digite 1
        Para remover fornecedor digite 2\t
        Para sair digite 0\n'''
                              ) 
        while add_remove not in ['0','1','2']:# requisito 3 verificação
            add_remove = input('''\tPara adicionar fornecedor digite 1
        Para remover fornecedor digite 2\t
        Para sair digite 0\n'''
                                  ) 
        if (add_remove == '1'):
            
            codigoFornecedor = str(input("Informe o código do fornecedor que irá adicionar:").lower())
            while codigoFornecedor in fornecedores["Código do fornecedor"]:
                
                print("Este código já está sendo utilizado, tente novamente.")
                codigoFornecedor = str(input("Informe o código do fornecedor que irá adicionar:").lower())
                
            nomeFornecedor = str(input("Informe o nome do fornecedor:").lower())
            telefoneFornecedor = str(input("Informe o telefone do fornecedor:").lower())
            emailFornecedor = str(input("Informe o email do fornecedor:").lower())
            
            
                          
            fornecedores["Código do fornecedor"].append(codigoFornecedor)
            fornecedores["Nome"].append(nomeFornecedor)
            fornecedores["Telefone"].append(telefoneFornecedor)
            fornecedores["E-mail"].append(emailFornecedor)
            
            print(f'''Os dados abaixo foram adicionados:
            
            Código: {codigoFornecedor}
            Nome: {nomeFornecedor}
            Telefone: {telefoneFornecedor}
            E-mail: {emailFornecedor}
            ''')
            
        elif (add_remove == '2'):
            if len(fornecedores["Código do fornecedor"]) == 0:
                print("Não há fornecedores cadastrados.")
                
            else:
                codigoFornecedor = str(input("Informe o código do fornecedor que irá remover:").lower())
                            
            if codigoFornecedor in fornecedores["Código do fornecedor"]:
                
                removerFornecedor = (fornecedores["Código do fornecedor"].index(codigoFornecedor))
                                            
                print(f'''Os dados abaixo foram deletados:
                
                Código: {fornecedores["Código do fornecedor"][removerFornecedor]}
                Nome: {fornecedores["Nome"][removerFornecedor]}
                Telefone: {fornecedores["Telefone"][removerFornecedor]}
                E-mail: {fornecedores["E-mail"][removerFornecedor]}
                ''')
                
                fornecedores["Nome"].pop(removerFornecedor)
                fornecedores["Telefone"].pop(removerFornecedor)
                fornecedores["E-mail"].pop(removerFornecedor)
                fornecedores["Código do fornecedor"].pop(removerFornecedor)
                
            
            else:
                print("Não há fornecedores cadastrados com este código para remover")
        else:
            menu_inicial()
            resposta = input('''Informe a opção desejada (digite 0 para sair): ''')
            
    elif (resposta == '2'):
        
        codigoRetornaFornecedor = input("Digite o código do fornecedor para obter informações (0 volta ao menu inicial): ").lower()
                
        if codigoRetornaFornecedor in fornecedores["Código do fornecedor"]:
                
            localizaFornecedor = (fornecedores["Código do fornecedor"].index(codigoRetornaFornecedor))
            print(f'''
            Dados do fornecedor
            Código: {fornecedores["Código do fornecedor"][localizaFornecedor]}                
            Nome: {fornecedores["Nome"][localizaFornecedor]}
            Telefone: {fornecedores["Telefone"][localizaFornecedor]}
            E-mail: {fornecedores["E-mail"][localizaFornecedor]}''')
            
        else:
            print("Não há fornecedor cadastrado com este código")
        if (codigoRetornaFornecedor == '0'):
            menu_inicial()
            resposta = input('''Informe a opção desejada (digite 0 para sair): ''')
            
    elif (resposta == '3'):  #opção secreta para teste
        print(f'''
        Códigos: {fornecedores['Código do fornecedor']}
        Nomes: {fornecedores['Nome']}
        Telefones: {fornecedores['Telefone']}
        E-mails: {fornecedores['E-mail']}
        ''')
        menu_inicial()
        resposta = input('''Informe a opção desejada (digite 0 para sair): ''')
    else:
        print('''
        Opção inválida. Tente novamente.
        ''')
        menu_inicial()
        resposta = input('''Informe a opção desejada (digite 0 para sair): ''')
# Out:
#     Selecione as opções de acordo com seus respectivos números:
#
#         1 Registrar ou Remover um fornecedor.
#         2 Informações gerais do fornecedor.
#         0 Fechar programa.
#
# Informe a opção desejada (digite 0 para sair): 1
# 	Para adicionar fornecedor digite 1
#         Para remover fornecedor digite 2
#         Para sair digite 0
# 1
# Informe o código do fornecedor que irá adicionar:asdasd
# Informe o nome do fornecedor:asd
# Informe o telefone do fornecedor:gdfg
# Informe o email do fornecedor:h
# Os dados abaixo foram adicionados:
#
#             Código: asdasd
#             Nome: asd
#             Telefone: gdfg
#             E-mail: h
#
# 	Para adicionar fornecedor digite 1
#         Para remover fornecedor digite 2
#         Para sair digite 0
# 1
# Informe o código do fornecedor que irá adicionar:dfgd
# Informe o nome do fornecedor:ert
# Informe o telefone do fornecedor:jh
# Informe o email do fornecedor:hj
# Os dados abaixo foram adicionados:
#
# ...

# %%
# Versão 1.0
# requisito 2 função menu
def menu_inicial():

    print('''
    Selecione as opções de acordo com seus respectivos números:
    
        1 Registrar ou Remover um fornecedor.
        2 Informações gerais do fornecedor.
        0 Fechar programa.
    ''')
    

# requisito 1 não há limite para cadastros
#listas e dicionários
baseFornecedores = {"Código do fornecedor" : [],
                "Nome": [],
                "Telefone": [],
                "E-mail" : []
               }


menu_inicial()
resposta = input('''Informe a opção desejada (digite 0 para sair): ''')

while resposta != '0': 
    
    if (resposta == '1'):
        
        add_remove = input('''\tPara adicionar fornecedor digite 1
        Para remover fornecedor digite 2\t
        Para sair digite 0\n'''
                              ) 
        while add_remove not in ['0','1','2']:# requisito 3 verificação
            add_remove = input('''\tPara adicionar fornecedor digite 1
        Para remover fornecedor digite 2\t
        Para sair digite 0\n'''
                                  ) 
        if (add_remove == '1'):
            codigoFornecedor = str(input("Informe o código do fornecedor que irá adicionar:"))
            nomeFornecedor = str(input("Informe o nome do fornecedor:"))
            telefoneFornecedor = str(input("Informe o telefone do fornecedor:"))
            emailFornecedor = str(input("Informe o email do fornecedor:"))
            
            codigoFornecedor = codigoFornecedor.lower()
            nomeFornecedor = nomeFornecedor.lower()
            telefoneFornecedor = telefoneFornecedor.lower()
            emailFornecedor = emailFornecedor.lower()
            
            fornecedores["Código do fornecedor"].append(codigoFornecedor)
            fornecedores["Nome"].append(nomeFornecedor)
            fornecedores["Telefone"].append(telefoneFornecedor)
            fornecedores["E-mail"].append(emailFornecedor)
            
            print(f'''Os dados abaixo foram adicionados:
            
            Código: {codigoFornecedor}
            Nome: {nomeFornecedor}
            Telefone: {telefoneFornecedor}
            E-mail: {emailFornecedor}
            ''')
            
        elif (add_remove == '2'):
            codigoFornecedor = str(input("Informe o código do fornecedor que irá remover:"))
            codigoFornecedor = codigo.lower()
            
            if codigoFornecedor in fornecedores["Código do fornecedor"]:
                
                removerFornecedor = (fornecedores["Código do fornecedor"].index(codigoFornecedor))
                                            
                print(f'''Os dados abaixo foram deletados:
                
                Código: {fornecedores["Código do fornecedor"][removerFornecedor]}
                Nome: {fornecedores["Nome"][removerFornecedor]}
                Telefone: {fornecedores["Telefone"][removerFornecedor]}
                E-mail: {fornecedores["E-mail"][removerFornecedor]}
                ''')
                
                fornecedores["Nome"].pop(removerFornecedor)
                fornecedores["Telefone"].pop(removerFornecedor)
                fornecedores["E-mail"].pop(removerFornecedor)
                fornecedores["Código do fornecedor"].pop(removerFornecedor)
                
                
            else:
                print("Não há fornecedores para remover")
        else:
            menu_inicial()
            resposta = input('''Informe a opção desejada (digite 0 para sair): ''')
            
    elif (resposta == '2'):
        
        codigoRetornaFornecedor = input("Digite o código do fornecedor para obter informações (0 volta ao menu inicial): ")
        codigoRetornaFornecedor = codigoRetornaFornecedor.lower()
        
        if codigoRetornaFornecedor in fornecedores["Código do fornecedor"]:
                
            localizaFornecedor = (fornecedores["Código do fornecedor"].index(codigoRetornaFornecedor))
            print(f'''
            Dados do fornecedor
            Código: {fornecedores["Código do fornecedor"][localizaFornecedor]}                
            Nome: {fornecedores["Nome"][localizaFornecedor]}
            Telefone: {fornecedores["Telefone"][localizaFornecedor]}
            E-mail: {fornecedores["E-mail"][localizaFornecedor]}''')
            
        else:
            print("Não há fornecedor cadastrado com este código")
        if (codigoRetornaFornecedor == '0'):
            menu_inicial()
            resposta = input('''Informe a opção desejada (digite 0 para sair): ''')
            
    elif (resposta == '3'):  #opção secreta para teste
        print(fornecedores)
    else:
        print('''
        Opção inválida. Tente novamente.
        ''')
        menu_inicial()
        resposta = input('''Informe a opção desejada (digite 0 para sair): ''')
